# %%
from joblib import load
import joblib
import pandas as pd
from datetime import datetime
import numpy as np

# %%
df = pd.read_excel("AKModeltesst_RE_raw export.xlsx")

# %%
df.shape
# Out:
# (46, 48)

# %%
details = df[['Domain', 'Name', 'Description', 'LinkedIn', 'Employee Estimate','Employee Growth (6 months)', 'Employee Growth (Annual)', 'Headquarters', 'Year Founded', 'Last Funding Amount', 'Last Funding Date', 'Total Funding Amount', 'Total Funding Rounds']]

# %%
data = df[['Employee Estimate', 'Employees on Professional Networks', 'Employee Growth (Monthly)', 'Employee Growth (Quarterly)', 'Employee Growth (6 months)', 'Employee Growth (Annual)', 'Headquarters', 'Year Founded', 'Last Funding Amount', 'Last Funding Date', 'Total Funding Amount', 'Total Funding Rounds', 'Business Model', 'Last Touch Date', 'Last Pipeline Decline Date']]

# %%
data
# Out:
#     Employee Estimate  Employees on Professional Networks  \
# 0                 237                                 236
# 1                 218                                  73
# 2                 199                                 393
# 3                 185                                 308
# 4                 183                                 183
# 5                 167                                 169
# 6                 163                                 163
# 7                 161                                 160
# 8                 140                                 141
# 9                 124                                 124
# 10                124                                 125
# 11                114                                 115
# 12                113                                 113
# 13                106                                 106
# 14                102                                 103
# 15                101                                 101
# 16                 93                                  93
# 17                 88                                  89
# 18                 74                                  74
# 19                 62                                  63
# 20                 61                                  62
# 21                 53                                  53
# 22                 50                                  50
# 23                 49                                  82
# 24                 49                                  91
# 25                 48                                  49
# 26                 46                                  96
# 27                 46                                  80
# 28                 46                                 125
# 29                 45                                  45
# 30                 44                                  44
# 31                 38                                  39
# 32                 36                                  37
# 33                 34                                  35
# 34                 32                                  33
# 35                 29                                  30
# 36                 29                                  30
# 37                 27                                  27
# 38                 23                                  23
# 39                 22                                  23
# 40                 21                                  22
# 41                 21                                  21
# 42                 18                                  19
# 43                 16                                  16
# 44                 15                                  15
# 45                 11                                   7
#
#    Employee Growth (Monthly) Employee Growth (Quarterly)  \
# 0                      0.43%                       2.61%
# 1                      8.96%                      30.36%
# 2                      2.34%                       2.34%
# 3                      1.65%                       0.33%
# 4                     -1.08%                       0.55%
# 5                      1.81%                       4.97%
# 6                      0.62%                       1.87%
# 7                     -3.03%                      -5.33%
# 8                     -2.76%                      -2.76%
# 9                          0                      -0.80%
# 10                    -0.79%                      -3.10%
# 11                    -4.96%                      -2.54%
# 12                    -0.88%                      -1.74%
# 13                     1.92%                       1.92%
# 14                    -1.90%                       3.00%
# 15                    -8.18%                     -15.13%
# 16                    -6.06%                      -4.12%
# 17                     2.30%                           0
# 18                    -3.90%                     -10.84%
# 19                         0                       6.78%
# 20                    -4.62%                      -4.62%
# 21                    -1.85%                           0
# 22                         0                      -1.96%
# 23                         0                       6.49%
# 24                     2.25%                       2.25%
# 25                     8.89%                       4.26%
# 26                     1.05%                      -2.04%
# 27                    -1.23%                       1.27%
# 28                    -2.34%                           0
# 29                    -4.26%                      -4.26%
# 30                    -4.35%                      -6.38%
# 31                         0                       2.63%
# 32                    -5.13%                       2.78%
# 33                         0                       6.06%
# 34                    -8.33%                     -10.81%
# 35                     3.45%                      11.11%
# 36                     3.45%                           0
# 37                    -3.57%                      -6.90%
# 38                    15.00%                      15.00%
# 39                    -4.17%                       9.52%
# 40                    -4.35%                       4.76%
# 41                    -4.55%                      -4.55%
# 42                         0                      -5.00%
# 43                    -5.88%                     -11.11%
# 44                    25.00%                      15.38%
# 45                   -12.50%                     -22.22%
#
#    Employee Growth (6 months) Employee Growth (Annual)  \
# 0                       8.26%                   11.85%
# 1                      55.32%                   82.50%
# 2                       5.36%                   62.40%
# 3                       0.98%                   -3.45%
# 4                      -5.18%                   -3.68%
# 5                       9.74%                   40.83%
# 6                       0.62%                   10.14%
# 7                     -11.60%                  -22.71%
# 8                      -4.73%                   -5.37%
# 9                           0                   14.81%
# 10                     -4.58%                  -10.71%
# 11                      4.55%                   16.16%
# 12                      3.67%                   14.14%
# 13                      7.07%                    3.92%
# 14                     13.19%                   83.93%
# 15                    -24.63%                  -30.34%
# 16                     -4.12%                   -4.12%
# 17                     -2.20%                    4.71%
# 18                    -14.94%                  -27.45%
# 19                     12.50%                   21.15%
# 20                     -8.82%                   -8.82%
# 21                     -3.64%                  -11.67%
# 22                     -1.96%                   -1.96%
# 23                     18.84%                   12.33%
# 24                      8.33%                  -23.53%
# 25                      2.08%                   11.36%
# 26                     -8.57%                  -10.28%
# 27                      6.67%                    5.26%
# 28                     -3.10%                    4.17%
# 29                      4.65%                    7.14%
# 30                     -8.33%                    4.76%
# 31                          0                   -7.14%
# 32                      2.78%                  -13.95%
# 33                      9.38%                   -2.78%
# 34                    -15.38%                  -13.16%
# 35                     30.43%                   76.47%
# 36                     -9.09%                  -23.08%
# 37                    -15.62%                  -37.21%
# 38                     15.00%                   25.00%
# 39                          0                        0
# 40                     -4.35%                   -4.35%
# 41                     -4.55%                  -12.50%
# 42                     11.76%                    5.56%
# 43                     -5.88%                  -11.11%
# 44                          0                    7.14%
# 45                          0                  -22.22%
#
#                   Headquarters  Year Founded  Last Funding Amount  \
# 0                 New York, NY          2015           50000000.0
# 1            San Francisco, CA          2016                  NaN
# 2                 New York, NY          2017            4000000.0
# 3            San Francisco, CA          2012           80000000.0
# 4                Missouri, USA          2014                  NaN
# 5                   Boston, MA          2015           15000000.0
# 6                   Reston, VA          2009                  NaN
# 7            San Francisco, CA          2012           30000000.0
# 8                 Blue Ash, OH          2010           17000000.0
# 9                 New York, NY          1999                  NaN
# 10                Carlsbad, CA          2014           10000000.0
# 11                New York, NY          2018           64000000.0
# 12            Perth, Australia          2017           38000000.0
# 13         West Palm Beach, FL          2016           41000000.0
# 14               Princeton, NJ          2020                  NaN
# 15                New York, NY          2016           16300000.0
# 16              Menlo Park, CA          2013           13000000.0
# 17                  Dallas, TX          2013           52000000.0
# 18           San Francisco, CA          2016                  NaN
# 19            Fort Collins, CO          2015            6500000.0
# 20             St. Charles, MO          2018            4000000.0
# 21                New York, NY          2017           14000000.0
# 22                  Boston, MA          1987                  NaN
# 23           San Francisco, CA          2019           40000000.0
# 24                  Boston, MA          2017                  NaN
# 25             California, USA          2015            9000000.0
# 26           San Francisco, CA          2014           43000000.0
# 27                  Reston, VA          2011                  NaN
# 28                  Mastic, NY          2014          125000000.0
# 29  Washington, Washington, DC          2013           10000000.0
# 30           San Francisco, CA          2012                  NaN
# 31                New York, NY          2016                  NaN
# 32               San Diego, CA          2016           12700000.0
# 33                New York, NY          2018            8000000.0
# 34               Hawthorne, NY          2015            3150000.0
# 35           San Francisco, CA          2020                  NaN
# 36               San Diego, CA          2018           15000000.0
# 37                New York, NY          2020           20000000.0
# 38                New York, NY          2022            8000000.0
# 39              Scottsdale, AZ          2005                  NaN
# 40                   Miami, FL          2016             100000.0
# 41                New York, NY          2020            8000000.0
# 42                 Chicago, IL          2011                  NaN
# 43                New York, NY          2017             150000.0
# 44        Huntington Beach, CA          2022            4000000.0
# 45            Myrtle Beach, SC          2016             120000.0
#
#    Last Funding Date  Total Funding Amount  Total Funding Rounds  \
# 0         2022-04-25           111970000.0                   5.0
# 1         2022-10-27             2700000.0                   5.0
# 2         2023-06-06           141040000.0                   7.0
# 3         2021-11-23           123550000.0                   7.0
# 4                NaN                   NaN                   NaN
# 5         2022-10-04            24500000.0                   4.0
# 6                NaN                   NaN                   5.0
# 7         2022-01-27           173060000.0                   8.0
# 8         2022-03-11            26980000.0                   4.0
# 9         2022-07-14                   NaN                   1.0
# 10        2020-04-21            22700000.0                   3.0
# 11        2023-10-27            93100000.0                   6.0
# 12        2022-12-14            69000000.0                   5.0
# 13        2020-10-21            41000000.0                   1.0
# 14        2021-04-20                   NaN                   1.0
# 15        2023-07-18            78770000.0                   8.0
# 16        2023-04-11            68349999.0                   7.0
# 17        2021-02-03            63700000.0                   6.0
# 18        2023-03-08            50930000.0                   8.0
# 19        2019-07-17            10450000.0                   4.0
# 20        2021-10-07             7000000.0                   4.0
# 21        2023-10-24            30760000.0                   6.0
# 22               NaN                   NaN                   NaN
# 23        2022-07-13            54900000.0                   4.0
# 24        2023-10-24             4030000.0                   5.0
# 25        2022-01-18            11580000.0                   5.0
# 26        2022-09-08            57760000.0                   8.0
# 27               NaN                   NaN                   0.0
# 28        2022-03-08           219580000.0                   7.0
# 29        2022-06-01            16200000.0                   4.0
# 30        2016-09-27                   NaN                   1.0
# 31        2019-01-31             3260000.0                   3.0
# 32        2022-11-15            12700000.0                   2.0
# 33        2021-04-29            10650000.0                   4.0
# 34        2022-05-03             3400000.0                   5.0
# 35        2022-01-01              130000.0                   3.0
# 36        2021-06-08            23750000.0                   5.0
# 37        2021-05-25            20000000.0                   1.0
# 38        2023-10-31             8000000.0                   2.0
# 39               NaN                   NaN                   0.0
# 40        2023-02-01             1110000.0                   3.0
# 41        2021-10-04             8000000.0                   1.0
# 42        2014-04-21                   NaN                   1.0
# 43        2021-01-28              150000.0                   1.0
# 44        2023-05-31             4000000.0                   1.0
# 45        2020-09-08              470000.0                   4.0
#
#       Business Model               Last Touch Date Last Pipeline Decline Date
# 0           Software                           NaN                        NaN
# 1        Marketplace  2024-06-15T12:54:39.000+0000                        NaN
# 2           Software                           NaN                        NaN
# 3           Software  2024-06-22T12:15:24.000+0000                        NaN
# 4           Software                           NaN                        NaN
# 5           Software  2024-06-22T12:15:51.000+0000                        NaN
# 6           Software                           NaN                        NaN
# 7           Software                           NaN                        NaN
# 8           Software  2024-06-22T12:15:05.000+0000                        NaN
# 9           Software                           NaN                        NaN
# 10          Software  2024-06-15T12:49:23.000+0000                        NaN
# 11          Software  2024-06-22T12:17:19.000+0000                        NaN
# 12               NaN  2024-07-13T22:55:13.000+0000                        NaN
# 13          Software                           NaN                        NaN
# 14          Software  2024-07-15T03:16:55.000+0000                 2024-03-06
# 15          Software                           NaN                        NaN
# 16          Software                           NaN                        NaN
# 17          Software                           NaN                        NaN
# 18          Software  2024-07-13T22:56:13.000+0000                        NaN
# 19          Software                           NaN                        NaN
# 20          Software                           NaN                        NaN
# 21          Software  2024-06-22T12:17:17.000+0000                        NaN
# 22          Services                           NaN                        NaN
# 23          Software  2024-07-13T22:52:31.000+0000                 2024-07-02
# 24          Software  2024-07-13T22:46:25.000+0000                 2022-11-09
# 25          Software  2024-06-24T20:39:46.000+0000                        NaN
# 26          Software  2024-06-22T12:15:24.000+0000                        NaN
# 27          Software                           NaN                        NaN
# 28          Software  2024-06-22T12:17:14.000+0000                        NaN
# 29          Software  2024-06-20T15:25:38.000+0000                        NaN
# 30          Software  2024-07-10T01:33:09.000+0000                        NaN
# 31          Software  2024-06-22T12:17:36.000+0000                        NaN
# 32          Software  2024-07-13T22:57:09.000+0000                 2022-11-16
# 33          Software  2024-06-22T12:16:54.000+0000                        NaN
# 34          Software  2024-07-13T22:52:31.000+0000                 2024-04-11
# 35          Software  2024-07-11T15:05:21.000+0000                 2024-05-09
# 36          Software                           NaN                        NaN
# 37  Software Enabled                           NaN                        NaN
# 38          Software  2024-06-15T12:53:27.000+0000                        NaN
# 39          Software                           NaN                        NaN
# 40          Software  2024-06-22T12:18:07.000+0000                        NaN
# 41          Software  2024-06-15T12:54:04.000+0000                        NaN
# 42          Software                           NaN                        NaN
# 43          Software  2024-06-15T12:54:04.000+0000                        NaN
# 44          Software  2024-06-15T12:54:08.000+0000                        NaN
# 45          Services                           NaN                        NaN

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# Assuming 'data' is your input DataFrame for predictions

# US location check
us_states = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']
data['is_us'] = data['Headquarters'].apply(lambda x: 0.5 if pd.isna(x) else int(any(state in x for state in us_states)))

# Calculate company age
current_year = datetime.now().year
data['company_age'] = current_year - data['Year Founded']

# Check for tech-enabled sectors
tech_enabled_sectors = ['Software', 'Software Enabled', 'Tech', 'Technology']
data['is_tech_enabled'] = data['Business Model'].apply(lambda x: 0 if pd.isna(x) else int(x in tech_enabled_sectors))

# Convert 'Employee Growth' columns to float
growth_columns = ['Employee Growth (Monthly)', 'Employee Growth (Quarterly)', 'Employee Growth (6 months)', 'Employee Growth (Annual)']
for col in growth_columns:
    data[col] = data[col].str.replace('%', '').astype(float)

# Process date columns
today = pd.Timestamp.now().tz_localize(None)
date_columns = ['Last Funding Date', 'Last Touch Date', 'Last Pipeline Decline Date']
for col in date_columns:
    data[col] = pd.to_datetime(data[col], errors='coerce').dt.tz_localize(None)
    data[f'Days Since {col}'] = (today - data[col]).dt.days

# Drop unnecessary columns
columns_to_drop = ['Headquarters', 'Year Founded', 'Business Model'] + date_columns
data = data.drop(columns=columns_to_drop)
# Out:
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['is_us'] = data['Headquarters'].apply(lambda x: 0.5 if pd.isna(x) else int(any(state in x for state in us_states)))
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['company_age'] = current_year - data['Year Founded']
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['is_tech_enabled'] = data['Business Model'].apply(lambda x: 0 if pd.isna(x) else int(x in tech_enabled_sectors))
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = data[col].str.replace('%', '').astype(float)
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = data[col].str.replace('%', '').astype(float)
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = data[col].str.replace('%', '').astype(float)
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = data[col].str.replace('%', '').astype(float)
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = pd.to_datetime(data[col], errors='coerce').dt.tz_localize(None)
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'Days Since {col}'] = (today - data[col]).dt.days
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = pd.to_datetime(data[col], errors='coerce').dt.tz_localize(None)
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'Days Since {col}'] = (today - data[col]).dt.days
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = pd.to_datetime(data[col], errors='coerce').dt.tz_localize(None)
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/1548002739.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'Days Since {col}'] = (today - data[col]).dt.days

# %%
loaded_model = load('model_cb.joblib')

# %%
predictions = loaded_model.predict(data)
predictions += 1

# %%
data
# Out:
#     Employee Estimate  Employees on Professional Networks  \
# 0                 237                                 236
# 1                 218                                  73
# 2                 199                                 393
# 3                 185                                 308
# 4                 183                                 183
# 5                 167                                 169
# 6                 163                                 163
# 7                 161                                 160
# 8                 140                                 141
# 9                 124                                 124
# 10                124                                 125
# 11                114                                 115
# 12                113                                 113
# 13                106                                 106
# 14                102                                 103
# 15                101                                 101
# 16                 93                                  93
# 17                 88                                  89
# 18                 74                                  74
# 19                 62                                  63
# 20                 61                                  62
# 21                 53                                  53
# 22                 50                                  50
# 23                 49                                  82
# 24                 49                                  91
# 25                 48                                  49
# 26                 46                                  96
# 27                 46                                  80
# 28                 46                                 125
# 29                 45                                  45
# 30                 44                                  44
# 31                 38                                  39
# 32                 36                                  37
# 33                 34                                  35
# 34                 32                                  33
# 35                 29                                  30
# 36                 29                                  30
# 37                 27                                  27
# 38                 23                                  23
# 39                 22                                  23
# 40                 21                                  22
# 41                 21                                  21
# 42                 18                                  19
# 43                 16                                  16
# 44                 15                                  15
# 45                 11                                   7
#
#     Employee Growth (Monthly)  Employee Growth (Quarterly)  \
# 0                        0.43                         2.61
# 1                        8.96                        30.36
# 2                        2.34                         2.34
# 3                        1.65                         0.33
# 4                       -1.08                         0.55
# 5                        1.81                         4.97
# 6                        0.62                         1.87
# 7                       -3.03                        -5.33
# 8                       -2.76                        -2.76
# 9                         NaN                        -0.80
# 10                      -0.79                        -3.10
# 11                      -4.96                        -2.54
# 12                      -0.88                        -1.74
# 13                       1.92                         1.92
# 14                      -1.90                         3.00
# 15                      -8.18                       -15.13
# 16                      -6.06                        -4.12
# 17                       2.30                          NaN
# 18                      -3.90                       -10.84
# 19                        NaN                         6.78
# 20                      -4.62                        -4.62
# 21                      -1.85                          NaN
# 22                        NaN                        -1.96
# 23                        NaN                         6.49
# 24                       2.25                         2.25
# 25                       8.89                         4.26
# 26                       1.05                        -2.04
# 27                      -1.23                         1.27
# 28                      -2.34                          NaN
# 29                      -4.26                        -4.26
# 30                      -4.35                        -6.38
# 31                        NaN                         2.63
# 32                      -5.13                         2.78
# 33                        NaN                         6.06
# 34                      -8.33                       -10.81
# 35                       3.45                        11.11
# 36                       3.45                          NaN
# 37                      -3.57                        -6.90
# 38                      15.00                        15.00
# 39                      -4.17                         9.52
# 40                      -4.35                         4.76
# 41                      -4.55                        -4.55
# 42                        NaN                        -5.00
# 43                      -5.88                       -11.11
# 44                      25.00                        15.38
# 45                     -12.50                       -22.22
#
#     Employee Growth (6 months)  Employee Growth (Annual)  Last Funding Amount  \
# 0                         8.26                     11.85           50000000.0
# 1                        55.32                     82.50                  NaN
# 2                         5.36                     62.40            4000000.0
# 3                         0.98                     -3.45           80000000.0
# 4                        -5.18                     -3.68                  NaN
# 5                         9.74                     40.83           15000000.0
# 6                         0.62                     10.14                  NaN
# 7                       -11.60                    -22.71           30000000.0
# 8                        -4.73                     -5.37           17000000.0
# 9                          NaN                     14.81                  NaN
# 10                       -4.58                    -10.71           10000000.0
# 11                        4.55                     16.16           64000000.0
# 12                        3.67                     14.14           38000000.0
# 13                        7.07                      3.92           41000000.0
# 14                       13.19                     83.93                  NaN
# 15                      -24.63                    -30.34           16300000.0
# 16                       -4.12                     -4.12           13000000.0
# 17                       -2.20                      4.71           52000000.0
# 18                      -14.94                    -27.45                  NaN
# 19                       12.50                     21.15            6500000.0
# 20                       -8.82                     -8.82            4000000.0
# 21                       -3.64                    -11.67           14000000.0
# 22                       -1.96                     -1.96                  NaN
# 23                       18.84                     12.33           40000000.0
# 24                        8.33                    -23.53                  NaN
# 25                        2.08                     11.36            9000000.0
# 26                       -8.57                    -10.28           43000000.0
# 27                        6.67                      5.26                  NaN
# 28                       -3.10                      4.17          125000000.0
# 29                        4.65                      7.14           10000000.0
# 30                       -8.33                      4.76                  NaN
# 31                         NaN                     -7.14                  NaN
# 32                        2.78                    -13.95           12700000.0
# 33                        9.38                     -2.78            8000000.0
# 34                      -15.38                    -13.16            3150000.0
# 35                       30.43                     76.47                  NaN
# 36                       -9.09                    -23.08           15000000.0
# 37                      -15.62                    -37.21           20000000.0
# 38                       15.00                     25.00            8000000.0
# 39                         NaN                       NaN                  NaN
# 40                       -4.35                     -4.35             100000.0
# 41                       -4.55                    -12.50            8000000.0
# 42                       11.76                      5.56                  NaN
# 43                       -5.88                    -11.11             150000.0
# 44                         NaN                      7.14            4000000.0
# 45                         NaN                    -22.22             120000.0
#
#     Total Funding Amount  Total Funding Rounds  is_us  company_age  \
# 0            111970000.0                   5.0      1            9
# 1              2700000.0                   5.0      1            8
# 2            141040000.0                   7.0      1            7
# 3            123550000.0                   7.0      1           12
# 4                    NaN                   NaN      0           10
# 5             24500000.0                   4.0      1            9
# 6                    NaN                   5.0      1           15
# 7            173060000.0                   8.0      1           12
# 8             26980000.0                   4.0      1           14
# 9                    NaN                   1.0      1           25
# 10            22700000.0                   3.0      1           10
# 11            93100000.0                   6.0      1            6
# 12            69000000.0                   5.0      0            7
# 13            41000000.0                   1.0      1            8
# 14                   NaN                   1.0      1            4
# 15            78770000.0                   8.0      1            8
# 16            68349999.0                   7.0      1           11
# 17            63700000.0                   6.0      1           11
# 18            50930000.0                   8.0      1            8
# 19            10450000.0                   4.0      1            9
# 20             7000000.0                   4.0      1            6
# 21            30760000.0                   6.0      1            7
# 22                   NaN                   NaN      1           37
# 23            54900000.0                   4.0      1            5
# 24             4030000.0                   5.0      1            7
# 25            11580000.0                   5.0      0            9
# 26            57760000.0                   8.0      1           10
# 27                   NaN                   0.0      1           13
# 28           219580000.0                   7.0      1           10
# 29            16200000.0                   4.0      0           11
# 30                   NaN                   1.0      1           12
# 31             3260000.0                   3.0      1            8
# 32            12700000.0                   2.0      1            8
# 33            10650000.0                   4.0      1            6
# 34             3400000.0                   5.0      1            9
# 35              130000.0                   3.0      1            4
# 36            23750000.0                   5.0      1            6
# 37            20000000.0                   1.0      1            4
# 38             8000000.0                   2.0      1            2
# 39                   NaN                   0.0      1           19
# 40             1110000.0                   3.0      1            8
# 41             8000000.0                   1.0      1            4
# 42                   NaN                   1.0      1           13
# 43              150000.0                   1.0      1            7
# 44             4000000.0                   1.0      1            2
# 45              470000.0                   4.0      1            8
#
#     is_tech_enabled  Days Since Last Funding Date  Days Since Last Touch Date  \
# 0                 1                         820.0                         NaN
# 1                 0                         635.0                        38.0
# 2                 1                         413.0                         NaN
# 3                 1                         973.0                        31.0
# 4                 1                           NaN                         NaN
# 5                 1                         658.0                        31.0
# 6                 1                           NaN                         NaN
# 7                 1                         908.0                         NaN
# 8                 1                         865.0                        31.0
# 9                 1                         740.0                         NaN
# 10                1                        1554.0                        38.0
# 11                1                         270.0                        31.0
# 12                0                         587.0                         9.0
# 13                1                        1371.0                         NaN
# 14                1                        1190.0                         8.0
# 15                1                         371.0                         NaN
# 16                1                         469.0                         NaN
# 17                1                        1266.0                         NaN
# 18                1                         503.0                         9.0
# 19                1                        1833.0                         NaN
# 20                1                        1020.0                         NaN
# 21                1                         273.0                        31.0
# 22                0                           NaN                         NaN
# 23                1                         741.0                         9.0
# 24                1                         273.0                         9.0
# 25                1                         917.0                        28.0
# 26                1                         684.0                        31.0
# 27                1                           NaN                         NaN
# 28                1                         868.0                        31.0
# 29                1                         783.0                        32.0
# 30                1                        2856.0                        13.0
# 31                1                        2000.0                        31.0
# 32                1                         616.0                         9.0
# 33                1                        1181.0                        31.0
# 34                1                         812.0                         9.0
# 35                1                         934.0                        11.0
# 36                1                        1141.0                         NaN
# 37                1                        1155.0                         NaN
# 38                1                         266.0                        38.0
# 39                1                           NaN                         NaN
# 40                1                         538.0                        31.0
# 41                1                        1023.0                        38.0
# 42                1                        3746.0                         NaN
# 43                1                        1272.0                        38.0
# 44                1                         419.0                        38.0
# 45                0                        1414.0                         NaN
#
#     Days Since Last Pipeline Decline Date
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                  139.0
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                   21.0
# 24                                  622.0
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# 30                                    NaN
# 31                                    NaN
# 32                                  615.0
# 33                                    NaN
# 34                                  103.0
# 35                                   75.0
# 36                                    NaN
# 37                                    NaN
# 38                                    NaN
# 39                                    NaN
# 40                                    NaN
# 41                                    NaN
# 42                                    NaN
# 43                                    NaN
# 44                                    NaN
# 45                                    NaN

# %%
predictions
# Out:
# array([ 3,  5,  2, 10,  3,  3, 10, 10, 10,  5,  7,  8,  8, 10,  4,  7,  2,
#        10,  7,  5,  7,  7,  7,  6,  7, 10,  7,  6, 10, 10, 10,  7,  7,  7,
#         7, 10,  7, 10,  8,  4,  7, 10,  4,  4,  8,  1])

# %%
details['score']=predictions
# Out:
# /var/folders/jz/27btwlsn5hj2km5hc3rg4vfr0000gn/T/ipykernel_4478/4281648696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['score']=predictions

# %%
cols = details.columns.tolist()
cols = cols[-1:] + cols[:-1]
details = details[cols]

# %%
# Updating 'score' to 1 for specified conditions
details.loc[(details['Last Funding Amount'] > 40000000) | (details['Total Funding Amount'] > 150000000), 'score'] = 1

# Save to Excel without index
details.to_excel("final_output.xlsx", index=False)
